# %%
#build an image recognition model
#install cifar 10 dataset
#display images
#build training and testing datasets
#build traing model
#train and test model

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"
# Out:
# chatbot.ipynb		      movie_conversations.txt  Untitled1.ipynb
# dataset			      movie_lines.txt	       Untitled2.ipynb
# image_recognition.ipynb       node_operator.ipynb      Untitled3.ipynb
# linear_regretion.ipynb	      Untitled		       Untitled4.ipynb
# mnist_leNet-checkpoint.ipynb  Untitled0.ipynb	       Untitled5.ipynb

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d58b3305-7859-40d8-98ed-77d7be7ee1e0" name="files[]" multiple disabled />
#      <output id="result-d58b3305-7859-40d8-98ed-77d7be7ee1e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-5c2e8a8d365b> in <module>()
#       1 from google.colab import files
# ----> 2 files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
# ...

# %%
sdef unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict
# Out:
#   File "<ipython-input-106-589011b24c99>", line 1
#     sdef unpickle(file):
#                 ^
# SyntaxError: invalid syntax

# %%
from PIL import Image

# %%
cat_image_pathname = 'cat.jpeg'

# %%
cat_image = Image.open(cat_image_pathname)

# %%
cat_image.show()

# %%
cat_image_pathname1= input("Enter image pathname :")
image = Image.open(cat_image_pathname1)
image.show()

# %%
from keras.datasets import cifar10

# %%
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer','dog','frog','horse','ship','truck']  #labels( indexes to each and every folder of dataser)

# %%
(X_train, y_train),(X_test, y_test) = cifar10.load_data()
#X_train= 50000 training images, y_train =50000 labels
#X_test = 10000 testing images , y_test = 10000 testing labels
#training and testing images will produce pixes in terms of arrays

# %%
index=50
display_img = X_train[index]
display_label = y_train[index][0]

# %%
print(display_label)
print(display_img)
# Out:
# 9
# [[[ 16  76  74]
#   [ 17  77  75]
#   [ 17  77  75]
#   ...
#   [ 62 106  87]
#   [ 55  99  80]
#   [ 51  94  75]]
#
#  [[ 16  76  74]
#   [ 16  76  74]
#   [ 15  75  74]
#   ...
#   [ 62 109  84]
#   [ 58 105  80]
#   [ 52 100  75]]
#
#  [[ 16  76  74]
#   [ 15  75  73]
#   [ 15  75  73]
#   ...
#   [ 57 110  79]
#   [ 59 111  80]
#   [ 56 109  78]]
#
#  ...
#
#  [[ 96 110 138]
#   [114 127 159]
#   [119 132 167]
#   ...
#   [128 135 153]
#   [120 130 145]
#   [117 131 142]]
#
#  [[118 132 159]
#   [100 113 145]
#   [114 126 163]
#   ...
#   [139 146 159]
#   [131 140 153]
#   [121 134 147]]
#
#  [[144 148 173]
#   [136 140 168]
#   [105 114 143]
#   ...
#   [145 151 170]
#   [137 144 163]
#   [131 141 158]]]

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(display_img)
plt.show()
# 32 * 32 pixel blur image

# %%
print(labels[display_label])
# Out:
# truck

# %%
# input from user and using PIL tensoflow library
index=int(input("Enter an image index :"))
display_img = X_train[index]
plt.imshow(display_img)
plt.show()
#print(labels[display_label])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# ...

# %%
index=int(input("Enter an image index :"))
color_display_img = X_train[index]
red_image = Image.fromarray(color_display_img)
red,green,blue= red_image.split()
plt.imshow(green, cmap="Greens")
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD
from keras.constraints import maxnorm

# %%
model = Sequential()
model.add(Conv2D(32,(3,3), input_shape=(32,32,3), activation='relu' ,padding='same',kernel_constraint=maxnorm(3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(512 ,activation='relu' ,kernel_constraint=maxnorm(3)))
model.add(Dropout(0.5))
model.add(Dense(10,activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.01),metrics=['accuracy'])

# %%
import h5py

# %%
from keras.utils import np_utils
new_X_train = X_train.astype('float32')
new_X_test = X_train.astype('float32')
new_X_train /=255
new_X_test /=255
new_Y_train = np_utils.to_categorical(y_train)
new_Y_test = np_utils.to_categorical(y_test)
#model.fit(new_X_train, new_Y_train, epochs=10, batch_size=32)

# %%
model.fit(new_X_train, new_Y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 50000/50000 [==============================] - 129s 3ms/step - loss: 1.6442 - acc: 0.4154
# Epoch 2/10
# 50000/50000 [==============================] - 129s 3ms/step - loss: 1.4941 - acc: 0.4655
# Epoch 3/10
# 50000/50000 [==============================] - 128s 3ms/step - loss: 1.3961 - acc: 0.5015
# Epoch 4/10
# 50000/50000 [==============================] - 131s 3ms/step - loss: 1.3276 - acc: 0.5296
# Epoch 5/10
# 50000/50000 [==============================] - 130s 3ms/step - loss: 1.2693 - acc: 0.5497
# Epoch 6/10
# 50000/50000 [==============================] - 129s 3ms/step - loss: 1.2170 - acc: 0.5689
# Epoch 7/10
# 50000/50000 [==============================] - 130s 3ms/step - loss: 1.1774 - acc: 0.5839
# Epoch 8/10
# 50000/50000 [==============================] - 130s 3ms/step - loss: 1.1374 - acc: 0.5960
# Epoch 9/10
# 50000/50000 [==============================] - 129s 3ms/step - loss: 1.1030 - acc: 0.6116
# Epoch 10/10
# ...

# %%
import h5py
model.save('trained_model.h5')

# %%
# !pip install h5py

# %%
import h5py

# %%
model.save("Training.h5")
